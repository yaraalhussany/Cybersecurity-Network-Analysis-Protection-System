# %%
import joblib
#model = joblib.load('isolation_forest_model.pkl')
model=joblib.load('random_forest_network_model.pkl')
#model=joblib.load('xgboost_tuned_network_model.pkl')
# Out:
# c:\Users\User\radioconda\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\User\radioconda\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\user\radioconda\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\user\radioconda\lib\site-packages (from xgboost) (2.2.3)
# Requirement already satisfied: scipy in c:\users\user\radioconda\lib\site-packages (from xgboost) (1.15.2)

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 3.2.0

# %%
import sklearn
import pandas as pd
import numpy as np
dataset=pd.read_csv('dataset.csv',header=None)
X=dataset.drop(columns=[15])
model.predict(X)
# Out:
# c:\Users\User\radioconda\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([3])
